# %%
# -*- coding: utf-8 -*-
import pymysql , pandas as pd,os
import boto3
import warnings,sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")

bucket_name='ahapaibcpilotrun2016'
session = boto3.Session(aws_access_key_id="AKIAIDTOKR43237RMFPA", aws_secret_access_key="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")
resource = session.resource('s3')
client = session.client('s3')    

config = {
    'user': 'reports',
    'password': 'Repo123$$',
    'host': 'ipsnvpvdadmsq02.ci4cevqynqdx.us-east-1.rds.amazonaws.com',
    'database':'RiskAdjustment_IBC_2017_Analytics'
}
config1 = {
    'user': 'reports',
    'passwd': 'Repo123$$',
    'host': 'ipsnvpvdadmsq02.ci4cevqynqdx.us-east-1.rds.amazonaws.com',
    'database':'RiskAdjustment_IBC_2017_Analytics'
}


q="""

#CREATE temporary TABLE test as
select distinct a.submission_id,b.chart_id, a.start_offset, a.end_offset
from pages a inner join submissions b on a.submission_id = b.id
where a.submission_id 
in ('9e88fd87-4c0d-4521-a3f1-92248ebb7dd2',
'b60be577-7f40-4f91-a29e-7e4b87e8bd4c',
'da667f71-4d22-4851-963e-3dc88030046c',
'e43f4ffa-7141-4083-9f47-b18194e8f7c6',
'be0017db-728e-400c-bca7-119844acf1d5',
'8dfdfdb2-58b6-422a-ab88-9c66549cb67c',
'9e367f1d-0325-4f27-a9c7-022f47d5658c',
'30b05f66-f826-44be-b5d7-ad7f800ace88',
'231196db-0a8c-4e1a-bb4e-e1259db2b5de',
'4c27d65a-c3b0-4110-b144-aa9e6b34687b',
'2f1ea4f5-a0c1-4d00-b803-44747fa6affe',
'cae51b27-4d14-4ba8-8492-a7571c8d46e4',
'd5b9aec0-cdd5-40b8-8566-5291954caa0a',
'fe5c76b4-7ca1-4e0b-a1c8-b2c2fcf65de4',
'f8b32b4f-9cf5-4b82-acfa-fd7dab9f36b9',
'00f78f22-672a-4b1a-9889-5ef4dcceb464',
'b014cba4-4fcd-4bf7-b71f-abdb602ec23b',
'87a3492e-d05c-4674-a16e-6cdc469163ff',
'1d81fe38-93c1-4c9e-bade-32235bd2819f',
'29081b83-566d-4525-9397-2aa7f6c37d3f',
'2d7a33cc-dae2-49a6-b2dd-7062a639656d',
'7f807212-1e50-4587-be78-f23f37619c6b',
'0344c75f-979b-4ada-9189-eb959d821894',
'06554729-1d9a-4262-8070-6d8c4ab3e1d9',
'38e52388-0514-4f2f-a57c-3a844a879ac8',
'f43160be-9885-4138-986d-0f0614ea9c87',
'b17e852b-db3b-48b5-9481-8a710e93ac50',
'c64ca70e-4d6b-4606-b6d1-9ec901f3e7db',
'ed5f1561-1d0e-47a6-9e67-51b506ed1961',
'a970a4c9-3f44-4805-ba89-c65ac54c1834',
'177c1cc5-8380-4572-a9a4-7b69ef9ce32a',
'b5bb9e06-7d82-45bb-89f9-9f141d9edfa4',
'3e5c98d1-34dd-44a4-ab65-1fb363aa8042',
'8987ea77-514b-4bd2-ba98-d5aae87d18e1',
'a9f4690f-5022-4912-ac79-b90978f5e02c',
'9a35297e-ed2e-43a9-9ecc-549337212843',
'276d2cbf-2df6-48e2-8996-038b76be884b',
'0ea4fd0d-88f0-42c1-af37-d8432bdd0a96',
'070ed7b1-74ec-4478-b5ef-3b06f70416f0',
'62a9a2c7-963c-40e1-8af0-5700b3e6447f',
'9c63bc82-380e-4b91-8c2d-b67fc8104974',
'acbcd7c1-cccd-42d5-8085-291372f1988c',
'5a66c2e5-222a-44c2-96ba-1b5b28351544',
'c15915fa-02fe-4a3e-972d-3a0909bd4c23',
'832675eb-9652-4a1c-aebe-25d49e1ecba4',
'c2c04ccd-b6dc-4825-963a-caa847592ef8',
'15368c85-824c-4ffa-ba80-2fe5d5f8e8c4',
'660439db-1b2c-48f6-bd73-ff938120e689',
'76467179-9355-4f4b-8059-0af9553ae4cb',
'b3094ff3-afc2-458c-bdf7-834edc11caee',
'ccda6f6e-fc0b-4c7b-914e-bfefa9c5b61f',
'0f741c2a-2beb-4af3-bbdd-2559e735bfcb',
'5e5be1d9-4e97-4f8d-84ee-9738d78985fd',
'27604bb8-b1e1-4ed5-907a-123db32cb147',
'99784bb0-c1c8-486f-a5ff-4b8fdb33875d',
'd9512baf-6fd7-41cc-a2c6-478982739730',
'836fd51d-d15d-4e2b-8167-21a80b16bf72',
'de0f237f-7ef3-4328-ba1a-549654e09cc3',
'017e520d-ce43-4f46-bab4-4e247a1a7b73',
'3a80c7a5-52bd-4f76-a748-e9d632fb4ba4',
'8f12233b-690b-44ab-87f8-57361de2256f',
'271d553b-12f1-4740-8c5d-5d054abb0463',
'45d6c015-9210-41ad-9aa7-280f901aa1f6',
'46acce2c-24c1-4d19-846c-c8c3fed47d4b',
'2d308661-03ac-4497-bbb0-b0155b65c714',
'bdf1bc75-c45e-44bf-b0cd-b4fd2a7651a0',
'b4dce99e-08b3-45f4-862d-4b1753645fea',
'808bfda6-cba2-4aef-9171-3b11e14fc66f',
'9f1f0451-7267-427b-b88b-fd98552020f0',
'45370355-5114-496f-b3a5-35969ee862d1',
'fa40bd01-2285-433e-a27b-865f369e0708',
'53cfdc37-f281-4ac1-8674-3d337ba2ba97',
'997d1279-fedb-4328-abaf-efde3144607c',
'7a83f2a8-2054-44a5-aa96-4e7ee0673659',
'c98556cc-069d-4edd-98c4-c62326552851',
'b8ac094f-a0fb-4f7e-9a59-e4bbdcee9ab1',
'ca025354-2e17-424f-bf54-600685c51f35',
'0478acee-65b8-493c-afc8-376bce535a8a',
'c79151b4-049d-456f-9c8f-41534787a2b9',
'999724e2-a980-4502-bb9e-d44b8a516c32',
'83b7dd2c-ea16-4d8d-a71c-842b83aa93d6',
'afa755c5-f1d8-4ed8-b6e5-73cc46379c30');
"""
try:clause=open('clause.txt','r').read()
except:clause=''
q2="""
select * from test  {};
""".format(clause)
connection = pymysql.connect (**config1)
cursor = connection.cursor()
query=q.split(';')
query=query[:-1]
for q1 in query:
    cursor.execute(q1)
    cursor.connection.commit()
cursor.execute(q2)
res=cursor.fetchall()
#print(res)
a=[list(row)for row in res  ]
c=[a[0]for a in cursor.description]

df=pd.DataFrame(a,columns=c)
data={}
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# /opt/conda/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /opt/conda/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import pymysql , pandas as pd,os
import numpy as np
import boto3
import warnings,sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")

bucket_name='ahapaibcpilotrun2016'
session = boto3.Session(aws_access_key_id="AKIAIDTOKR43237RMFPA", aws_secret_access_key="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")
resource = session.resource('s3')
client = session.client('s3')

# %% [markdown]
# #### download data for not doctor notes and agreed charts

# %%
# did it in 106 server and move the file to here
df=pd.read_csv('selectnotdoctornotes_test1000_pageoffset.csv')
#df=pd.read_csv('selectnotdoctornotes_train1000_pageoffset.csv')
#df=pd.read_csv('selectagreed_train1000_pageoffset.csv')
#df=pd.read_csv('selectagreed_test1000_pageoffset.csv')

# %%
len(df)
# Out:
# 32951

# %%
df.head()
# Out:
#                           submission_id  \
# 0  001efa40-7ff5-4240-8a9a-eda81c695641
# 1  001efa40-7ff5-4240-8a9a-eda81c695641
# 2  001efa40-7ff5-4240-8a9a-eda81c695641
# 3  001efa40-7ff5-4240-8a9a-eda81c695641
# 4  001efa40-7ff5-4240-8a9a-eda81c695641
#
#                                             chart_id  start_offset  end_offset
# 0  IBXRMA2018_MULT_1217627100010001_HMK_026360992...             0         497
# 1  IBXRMA2018_MULT_1217627100010001_HMK_026360992...           497         983
# 2  IBXRMA2018_MULT_1217627100010001_HMK_026360992...           983        1338
# 3  IBXRMA2018_MULT_1217627100010001_HMK_026360992...          1338        2077
# 4  IBXRMA2018_MULT_1217627100010001_HMK_026360992...          2077        2809

# %%
df['chart_id'].nunique()   # close to 1000 charts chart ids for each
# Out:
# 987

# %%
df1=df

# %%
df1['chart_id'] = df1['chart_id'].astype(str)
df1.dtypes
df1=df1[df1['chart_id'].str.contains('_pmh')!=True]  #  these charts cannot be downloaded
len(df1)
# Out:
# 31034

# %%
# get the data from S3
data1={}
try:os.mkdir('txt')
except:pass
def fetch(x):
    chartid,start,end=x.chart_id,x.start_offset,x.end_offset
    global data1
    if chartid not in data1:
        try:
            client.download_file('ahapaibcpilotrun2016','txt_full/'+chartid+'/'+chartid+'.txt','txt/'+chartid+'.txt' )
            print('txt_full/'+chartid+'/'+chartid+'.txt')
            data1[chartid]=open('txt/'+chartid+'.txt','r').read().replace('\n',' ')
            os.remove('txt/'+chartid+'.txt')       
    
            x['pagetext']=data1[chartid][start:end]
            
        except:
            print('txt_full/'+chartid+'/')
            client.download_file('ahapaibcpilotrun2016','txt_full/'+chartid+'.txt','txt/'+chartid+'.txt' )
            data1[chartid]=open('txt/'+chartid+'.txt','r').read().replace('\n',' ')
            os.remove('txt/'+chartid+'.txt') 
            x['pagetext']=data1[chartid][start:end]   # this text is from where?
            #x['pagetext']= text
           
    else:
            x['pagetext']=data1[chartid][start:end]
                      
    
    return x


df1[['pagetext']]=df1.apply(fetch ,axis=1)[['pagetext']]

#df['deleted_reason']=df.apply(dreason,axis=1)

#df=df[['chart_id', 'submission_id','start_offset','end_offset', 'pagetext']]
# Out:
# txt_full/IBXRMA2018_MULT_1217627100010001_HMK_026360992T_DEBRA_WEINER_002808842_2017_20180508084545/IBXRMA2018_MULT_1217627100010001_HMK_026360992T_DEBRA_WEINER_002808842_2017_20180508084545.txt
# txt_full/ibxrma2018_mult_1196591680010001_hmk_203385510a_helen_melchiorre_002806260_2017/ibxrma2018_mult_1196591680010001_hmk_203385510a_helen_melchiorre_002806260_2017.txt
# txt_full/IBXRMA2018_MULT_1217944680010001_HMK_211466888A_NATALE_CIMA_002820440_2017/IBXRMA2018_MULT_1217944680010001_HMK_211466888A_NATALE_CIMA_002820440_2017.txt
# txt_full/IBXRMA2018_MULT_1217909970010001_HMK_314540058A_PRUDENCE_PATTON_002821598_2017/IBXRMA2018_MULT_1217909970010001_HMK_314540058A_PRUDENCE_PATTON_002821598_2017.txt
# txt_full/IBXRMA2018_MULT_1216698520010001_HMK_172261863A_ELIZABETH_SHAW_002885776_2017/IBXRMA2018_MULT_1216698520010001_HMK_172261863A_ELIZABETH_SHAW_002885776_2017.txt
# ...

# %%
df1['flag']=1  # assign it with a class 1 for not doctor notes, for agreed, assign 0

# %%
len(df1)
# Out:
# 31034

# %%
df1.head()
# Out:
#                           submission_id  \
# 0  001efa40-7ff5-4240-8a9a-eda81c695641
# 1  001efa40-7ff5-4240-8a9a-eda81c695641
# 2  001efa40-7ff5-4240-8a9a-eda81c695641
# 3  001efa40-7ff5-4240-8a9a-eda81c695641
# 4  001efa40-7ff5-4240-8a9a-eda81c695641
#
#                                             chart_id  start_offset  \
# 0  IBXRMA2018_MULT_1217627100010001_HMK_026360992...             0
# 1  IBXRMA2018_MULT_1217627100010001_HMK_026360992...           497
# 2  IBXRMA2018_MULT_1217627100010001_HMK_026360992...           983
# 3  IBXRMA2018_MULT_1217627100010001_HMK_026360992...          1338
# 4  IBXRMA2018_MULT_1217627100010001_HMK_026360992...          2077
#
#    end_offset                                           pagetext  flag
# 0         497       5/7/2018   Weiner, Debra S (MI   Do you h...     1
# 1         983     loperam   with two eccentric blue globules-...     1
# 2        1338  ut he results a re-biopsy   8 mm punch biopsy ...     1
# ...

# %%
#df1.to_csv('agreed_testpagetext.csv')
#df1.to_csv('agreed_trainpagetext.csv')
#df1.to_csv('ndn_trainpagetext.csv')
df1.to_csv('ndn_testpagetext.csv')

# %% [markdown]
# ####  merge  data

# %%
df1=pd.read_csv('ndn_testpagetext.csv')
df2=pd.read_csv('agreed_testpagetext.csv')  # concat df1 and 2,   df3 and 4
df3=pd.read_csv('ndn_trainpagetext.csv')
df4=pd.read_csv('agreed_trainpagetext.csv')

# %%
traindata_pagelevel_2000charts=pd.concat([df3,df4])

# %%
testdata_pagelevel_2000charts=pd.concat([df1,df2])

# %%
traindata_pagelevel_2000charts.tail()
#testdata_pagelevel_2000charts.tail()
# Out:
#        Unnamed: 0                         submission_id  \
# 32878       32878  fffa9df6-a739-44e2-a177-e7824bbeab78
# 32879       32879  fffa9df6-a739-44e2-a177-e7824bbeab78
# 32880       32880  fffa9df6-a739-44e2-a177-e7824bbeab78
# 32881       32881  fffa9df6-a739-44e2-a177-e7824bbeab78
# 32882       32882  fffa9df6-a739-44e2-a177-e7824bbeab78
#
#                                                 chart_id  start_offset  \
# 32878  IBXRMA2018_MULT_1217428230010001_HMK_153301299...         43350
# 32879  IBXRMA2018_MULT_1217428230010001_HMK_153301299...         44573
# 32880  IBXRMA2018_MULT_1217428230010001_HMK_153301299...         45411
# 32881  IBXRMA2018_MULT_1217428230010001_HMK_153301299...         47451
# 32882  IBXRMA2018_MULT_1217428230010001_HMK_153301299...         49171
#
#        end_offset                                           pagetext  flag
# 32878       44573  be performed, COMPREHENSIVE METABOLIC PANEL W/...     0
# ...

# %%
# remove "Unnamed: 0"
traindata_pagelevel_2000charts=traindata_pagelevel_2000charts[['submission_id','chart_id','start_offset','end_offset','pagetext','flag']]
testdata_pagelevel_2000charts=testdata_pagelevel_2000charts[['submission_id','chart_id','start_offset','end_offset','pagetext','flag']]

# %%
# removing the  null text
#print(len(traindata_pagelevel_2000charts))
#traindata_pagelevel_2000charts = traindata_pagelevel_2000charts[pd.notnull(testdata_pagelevel_2000charts['pagetext'])]
#traindata_pagelevel_2000charts= traindata_pagelevel_2000charts.replace(np.nan,'',regex = True) # keep the Nan text or remove it? if order reversed, not deleting
print(len(traindata_pagelevel_2000charts))
# Out:
# 62826

# %%
# removing the  null text
print(len(testdata_pagelevel_2000charts))
testdata_pagelevel_2000charts = testdata_pagelevel_2000charts[pd.notnull(testdata_pagelevel_2000charts['pagetext'])]
testdata_pagelevel_2000charts= testdata_pagelevel_2000charts.replace(np.nan,'',regex = True) # keep the Nan text or remove it? if order reversed, not deleting
print(len(testdata_pagelevel_2000charts))
# Out:
# 64833
# 64287

# %%
traindata_pagelevel_2000charts.head()
# Out:
#    Unnamed: 0                         submission_id  \
# 0           0  00647fab-ae3b-40e7-83df-58dd0b6444de
# 1           1  00647fab-ae3b-40e7-83df-58dd0b6444de
# 2           2  00647fab-ae3b-40e7-83df-58dd0b6444de
# 3           3  00647fab-ae3b-40e7-83df-58dd0b6444de
# 4           4  00647fab-ae3b-40e7-83df-58dd0b6444de
#
#                                             chart_id  start_offset  \
# 0  IBXRMA2018_MULT_1230654640010001_HMK_193209773...             0
# 1  IBXRMA2018_MULT_1230654640010001_HMK_193209773...           150
# 2  IBXRMA2018_MULT_1230654640010001_HMK_193209773...           956
# 3  IBXRMA2018_MULT_1230654640010001_HMK_193209773...          1698
# 4  IBXRMA2018_MULT_1230654640010001_HMK_193209773...          4939
#
#    end_offset                                           pagetext  flag
# 0         150      Chart   Clare M. Byrnes   DOB: 06/04/1929 ...     1
# 1         956  s   Encounter 5 Date 11/06/2017  Diagnosis Uns...     1
# ...

# %%
# will not do preprocessing, because it removed all the special characters
# preprocessing, removing stop words
# remove stopwords
'''
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
'''
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
'''
traindata_pagelevel_2000charts['pagetext'] = traindata_pagelevel_2000charts['pagetext'].apply(lambda x: x.lower())
traindata_pagelevel_2000charts['pagetext'] = traindata_pagelevel_2000charts['pagetext'].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))
traindata_pagelevel_2000charts['pagetext']= traindata_pagelevel_2000charts['pagetext'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
traindata_pagelevel_2000charts['pagetext']= traindata_pagelevel_2000charts['pagetext'].str.findall('\w{4,}').str.join(' ')
'''

# %%
'''
testdata_pagelevel_2000charts['pagetext'] = testdata_pagelevel_2000charts['pagetext'].apply(lambda x: x.lower())
testdata_pagelevel_2000charts['pagetext'] = testdata_pagelevel_2000charts['pagetext'].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))
testdata_pagelevel_2000charts['pagetext']= testdata_pagelevel_2000charts['pagetext'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
testdata_pagelevel_2000charts['pagetext']= testdata_pagelevel_2000charts['pagetext'].str.findall('\w{4,}').str.join(' ')
'''

# %%
traindata_pagelevel_2000charts.to_csv('notdoctornote_4training_0416.csv')
testdata_pagelevel_2000charts.to_csv('notdoctornote_4testing_0416.csv')

# %% [markdown]
# ####  checking the text

# %%
import string

# %%
print(traindata_pagelevel_2000charts.iloc[0]['pagetext'])
# Out:
#     Chart   Clare M. Byrnes   DOB: 06/04/1929   From 01/01/2017 to 12/31/2017   04/24/2018 03:53 pmClare M. Byrnes DOB 06/04/1929Page 1/27   Encounter

# %%
traindata_pagelevel_2000charts.iloc[100]['pagetext']
# Out:
# '7073974   PENNSYLVANIA NEPHROLOGY ASSOCIATES, PC  SECTION ON RENAL DISEASES AND HYPERTENSION  PENNSYLVANIA HOSPITAL    Telephone: 215-829-8420   John D. Koethe, M.D., F.A,C.P.   Farm Journal Building, Suite 100  230 W. Washington Square  Philadelphia, PA 19106-3500      K. Adu Ntoso, M.D., F.A.C.P.  Chief of Section   Carmen Patrascu, M.D.   Fax: 215-829-8418   Pooneh Alborzi, M.D.     IEZZ1, JANET - (DOB: 07/18/1934)John D Koethe, MD   Date of Visit: 10/24/2017   Gender: Female   MRN: 7463-1   Appointment Type: F/U   Location of Service: PA Nephrology Associates -   Reason for Visit: CKD, HTN, Nephrolithiasis   Referring Physician: RUBIN, JOYCE - Fax 215-454-3625   Primary Care Physician: Rubin, Joyce - Fax 215-454-3625   Chief Complaint:   CKD, HTN, nephrolithiasis   History of Present Illness:   Ms. IEZZI is a 83 year-old White female with Hx. of DM, DJD ,SA, HTN, Nephrolithiasis and Stage 3   CKD who returned for nephrologic f/u.   Note longstanding Stage 3 CKD with increased ec
# ...

# %%
len(traindata_pagelevel_2000charts.iloc[100]['pagetext'].split(' '))
# Out:
# 498
